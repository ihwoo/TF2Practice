# %%
import tensorflow as tf
fashion_mnist=tf.keras.datasets.fashion_mnist
(train_X,train_Y), (test_X,test_Y)=fashion_mnist.load_data()
train_X=train_X/255.0
test_X=test_X/255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 3us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 6s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 1s 0us/step

# %%
print(train_X.shape,test_X.shape)
train_X=train_X.reshape(-1,28,28,1)
test_X=test_X.reshape(-1,28,28,1)
print(train_X.shape,test_X.shape)
# Out:
# (60000, 28, 28, 1) (10000, 28, 28, 1)
# (60000, 28, 28, 1) (10000, 28, 28, 1)
# 0

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
for c in range(16):
    plt.subplot(4,4,c+1,label=train_Y[c])
    plt.imshow(train_X[c].reshape(28,28),cmap='gray')
    
plt.show()

# %%
model=tf.keras.Sequential([
        tf.keras.layers.Conv2D(input_shape=(28,28,1), kernel_size=(3,3), filters=16),
        tf.keras.layers.MaxPool2D(strides=(2,2)),
        tf.keras.layers.Conv2D(kernel_size=(3,3),filters=32),
        tf.keras.layers.MaxPool2D(strides=(2,2)),
        tf.keras.layers.Conv2D(kernel_size=(3,3),filters=64),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(units=128, activation='relu'),
        tf.keras.layers.Dropout(rate=0.3),
        tf.keras.layers.Dense(units=10, activation='softmax')
    ])
model.compile(optimizer=tf.keras.optimizers.Adam(),
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 16)        160
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 32)        4640
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 22, 22, 64)        18496
# _________________________________________________________________
# flatten (Flatten)            (None, 30976)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               3965056
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 3,989,642
# Trainable params: 3,989,642
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(train_X,train_Y,epochs=25, validation_split=0.25)
# Out:
# Epoch 1/25
# 1407/1407 [==============================] - 87s 62ms/step - loss: 0.4702 - accuracy: 0.8342 - val_loss: 0.3814 - val_accuracy: 0.8626
# Epoch 2/25
# 1407/1407 [==============================] - 92s 65ms/step - loss: 0.3398 - accuracy: 0.8762 - val_loss: 0.3689 - val_accuracy: 0.8671
# Epoch 3/25
# 1407/1407 [==============================] - 90s 64ms/step - loss: 0.2883 - accuracy: 0.8948 - val_loss: 0.3733 - val_accuracy: 0.8680
# Epoch 4/25
# 1407/1407 [==============================] - 90s 64ms/step - loss: 0.2424 - accuracy: 0.9101 - val_loss: 0.3975 - val_accuracy: 0.8703
# Epoch 5/25
# 1407/1407 [==============================] - 91s 65ms/step - loss: 0.2169 - accuracy: 0.9194 - val_loss: 0.3984 - val_accuracy: 0.8735
# Epoch 6/25
# 1407/1407 [==============================] - 90s 64ms/step - loss: 0.1895 - accuracy: 0.9306 - val_loss: 0.4294 - val_accuracy: 0.8717
# Epoch 7/25
# 1407/1407 [==============================] - 87s 62ms/step - loss: 0.1638 - accuracy: 0.9392 - val_loss: 0.5000 - val_accuracy: 0.8635
# Epoch 8/25
# 1407/1407 [==============================] - 87s 62ms/step - loss: 0.1543 - accuracy: 0.9422 - val_loss: 0.4826 - val_accuracy: 0.8687
# Epoch 9/25
# 1407/1407 [==============================] - 87s 62ms/step - loss: 0.1369 - accuracy: 0.9494 - val_loss: 0.5334 - val_accuracy: 0.8716
# Epoch 10/25
# 1407/1407 [==============================] - 88s 62ms/step - loss: 0.1260 - accuracy: 0.9542 - val_loss: 0.5894 - val_accuracy: 0.8601
# Epoch 11/25
# 1407/1407 [==============================] - 88s 63ms/step - loss: 0.1180 - accuracy: 0.9571 - val_loss: 0.6808 - val_accuracy: 0.8641
# Epoch 12/25
# 1407/1407 [==============================] - 88s 62ms/step - loss: 0.1044 - accuracy: 0.9616 - val_loss: 0.7843 - val_accuracy: 0.8548
# Epoch 13/25
# 1407/1407 [==============================] - 88s 63ms/step - loss: 0.0966 - accuracy: 0.9652 - val_loss: 0.7819 - val_accuracy: 0.8642
# Epoch 14/25
# 1407/1407 [==============================] - 88s 63ms/step - loss: 0.0950 - accuracy: 0.9667 - val_loss: 0.7922 - val_accuracy: 0.8609
# Epoch 15/25
# 1407/1407 [==============================] - 88s 63ms/step - loss: 0.0889 - accuracy: 0.9698 - val_loss: 0.8188 - val_accuracy: 0.8613
# Epoch 16/25
# 1407/1407 [==============================] - 88s 63ms/step - loss: 0.0823 - accuracy: 0.9718 - val_loss: 0.8065 - val_accuracy: 0.8668
# Epoch 17/25
# 1407/1407 [==============================] - 88s 63ms/step - loss: 0.0809 - accuracy: 0.9720 - val_loss: 0.9243 - val_accuracy: 0.8621
# Epoch 18/25
# 1407/1407 [==============================] - 88s 63ms/step - loss: 0.0762 - accuracy: 0.9732 - val_loss: 0.9819 - val_accuracy: 0.8614
# Epoch 19/25
# 1407/1407 [==============================] - 89s 63ms/step - loss: 0.0736 - accuracy: 0.9752 - val_loss: 1.1478 - val_accuracy: 0.8617
# Epoch 20/25
# 1407/1407 [==============================] - 89s 63ms/step - loss: 0.0674 - accuracy: 0.9770 - val_loss: 1.0136 - val_accuracy: 0.8667
# Epoch 21/25
# 1407/1407 [==============================] - 89s 63ms/step - loss: 0.0593 - accuracy: 0.9790 - val_loss: 1.1033 - val_accuracy: 0.8631
# Epoch 22/25
# 1407/1407 [==============================] - 89s 63ms/step - loss: 0.0742 - accuracy: 0.9756 - val_loss: 1.1794 - val_accuracy: 0.8572
# Epoch 23/25
# 1407/1407 [==============================] - 89s 63ms/step - loss: 0.0718 - accuracy: 0.9765 - val_loss: 1.1385 - val_accuracy: 0.8611
# Epoch 24/25
# 1407/1407 [==============================] - 88s 63ms/step - loss: 0.0574 - accuracy: 0.9817 - val_loss: 1.1598 - val_accuracy: 0.8671
# Epoch 25/25
# 1407/1407 [==============================] - 89s 63ms/step - loss: 0.0598 - accuracy: 0.9804 - val_loss: 1.2863 - val_accuracy: 0.8636

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
plt.plot(history.history['loss'],'b-',label='loss')
plt.plot(history.history['val_loss'],'r--',label='val_loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'],'b-',label='accuracy')
plt.plot(history.history['val_accuracy'],'r--',label='val_accuracy')
plt.xlabel('Epoch')
plt.ylim(0.7,1)
plt.legend()

plt.show()
model.evaluate(test_X,test_Y,verbose=0)
# Out:
# [1.3795431852340698, 0.8623999953269958]

# %%
import numpy as np

idx=3
result=model.predict(test_X[idx].reshape(-1,28,28,1))
print(f'predicted table>\n{result},\answer> {test_Y[idx]} ')
predicted_label=np.argmax(result)
print(predicted_label==test_Y[idx])
# Out:
# predicted table>
# [[0.0000000e+00 1.0000000e+00 0.0000000e+00 2.0128648e-36 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00]],nswer> 1
# True
