# %%
import tensorflow as tf
fashion_mnist=tf.keras.datasets.fashion_mnist
(train_X,train_Y), (test_X,test_Y)=fashion_mnist.load_data()
train_X=train_X/255.0
test_X=test_X/255.0

# %%
print(train_X.shape,test_X.shape)
train_X=train_X.reshape(-1,28,28,1)
test_X=test_X.reshape(-1,28,28,1)
print(train_X.shape,test_X.shape)
# Out:
# (60000, 28, 28) (10000, 28, 28)
# (60000, 28, 28, 1) (10000, 28, 28, 1)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
for c in range(16):
    plt.subplot(4,4,c+1,label=train_Y[c])
    plt.imshow(train_X[c].reshape(28,28),cmap='gray')
    
plt.show()

# %%
model=tf.keras.Sequential([
        tf.keras.layers.Conv2D(input_shape=(28,28,1), kernel_size=(3,3), filters=16),
        tf.keras.layers.MaxPool2D(strides=(2,2)),
        tf.keras.layers.Conv2D(kernel_size=(3,3),filters=32),
        tf.keras.layers.MaxPool2D(strides=(2,2)),
        tf.keras.layers.Conv2D(kernel_size=(3,3),filters=64),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(units=128, activation='relu'),
        tf.keras.layers.Dropout(rate=0.3),
        tf.keras.layers.Dense(units=10, activation='softmax')
    ])
model.compile(optimizer=tf.keras.optimizers.Adam(),
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 16)        160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 64)          18496
# _________________________________________________________________
# flatten (Flatten)            (None, 576)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               73856
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 98,442
# Trainable params: 98,442
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(train_X,train_Y,epochs=25, validation_split=0.25)
# Out:
# Epoch 1/25
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.5769 - accuracy: 0.7903 - val_loss: 0.3966 - val_accuracy: 0.8543
# Epoch 2/25
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.3875 - accuracy: 0.8596 - val_loss: 0.3646 - val_accuracy: 0.8651
# Epoch 3/25
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.3424 - accuracy: 0.8745 - val_loss: 0.3225 - val_accuracy: 0.8845
# Epoch 4/25
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.3143 - accuracy: 0.8860 - val_loss: 0.3077 - val_accuracy: 0.8889
# Epoch 5/25
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.2908 - accuracy: 0.8932 - val_loss: 0.3001 - val_accuracy: 0.8919
# Epoch 6/25
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.2756 - accuracy: 0.8990 - val_loss: 0.2908 - val_accuracy: 0.8932
# Epoch 7/25
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.2585 - accuracy: 0.9049 - val_loss: 0.3033 - val_accuracy: 0.8869
# Epoch 8/25
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.2470 - accuracy: 0.9096 - val_loss: 0.2949 - val_accuracy: 0.8959
# Epoch 9/25
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.2349 - accuracy: 0.9134 - val_loss: 0.2936 - val_accuracy: 0.8933
# Epoch 10/25
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.2243 - accuracy: 0.9162 - val_loss: 0.2933 - val_accuracy: 0.8957
# Epoch 11/25
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.2158 - accuracy: 0.9182 - val_loss: 0.3050 - val_accuracy: 0.8961
# Epoch 12/25
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.2096 - accuracy: 0.9200 - val_loss: 0.2977 - val_accuracy: 0.8968
# Epoch 13/25
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.1999 - accuracy: 0.9251 - val_loss: 0.2979 - val_accuracy: 0.9001
# Epoch 14/25
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.1939 - accuracy: 0.9270 - val_loss: 0.3187 - val_accuracy: 0.9003
# Epoch 15/25
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.1855 - accuracy: 0.9300 - val_loss: 0.3085 - val_accuracy: 0.9002
# Epoch 16/25
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.1812 - accuracy: 0.9312 - val_loss: 0.3215 - val_accuracy: 0.8973
# Epoch 17/25
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.1765 - accuracy: 0.9337 - val_loss: 0.3418 - val_accuracy: 0.8976
# Epoch 18/25
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.1697 - accuracy: 0.9351 - val_loss: 0.3477 - val_accuracy: 0.9005
# Epoch 19/25
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.1678 - accuracy: 0.9360 - val_loss: 0.3426 - val_accuracy: 0.8987
# Epoch 20/25
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.1633 - accuracy: 0.9388 - val_loss: 0.3396 - val_accuracy: 0.9027
# Epoch 21/25
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.1577 - accuracy: 0.9408 - val_loss: 0.3575 - val_accuracy: 0.8981
# Epoch 22/25
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.1594 - accuracy: 0.9404 - val_loss: 0.3384 - val_accuracy: 0.9021
# Epoch 23/25
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.1503 - accuracy: 0.9435 - val_loss: 0.3559 - val_accuracy: 0.8909
# Epoch 24/25
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.1479 - accuracy: 0.9444 - val_loss: 0.3669 - val_accuracy: 0.8957
# Epoch 25/25
# 1407/1407 [==============================] - 3s 2ms/step - loss: 0.1465 - accuracy: 0.9445 - val_loss: 0.3707 - val_accuracy: 0.8987

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
plt.plot(history.history['loss'],'b-',label='loss')
plt.plot(history.history['val_loss'],'r--',label='val_loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'],'b-',label='accuracy')
plt.plot(history.history['val_accuracy'],'r--',label='val_accuracy')
plt.xlabel('Epoch')
plt.ylim(0.7,1)
plt.legend()

plt.show()
model.evaluate(test_X,test_Y,verbose=0)
# Out:
# [0.3837329149246216, 0.8970000147819519]

# %%
import numpy as np

idx=3
result=model.predict(test_X[idx].reshape(-1,28,28,1))
print(f'predicted table>\n{result},\answer> {test_Y[idx]} ')
predicted_label=np.argmax(result)
print(predicted_label==test_Y[idx])
# Out:
# predicted table>
# [[6.5770557e-22 1.0000000e+00 2.2804090e-25 1.0938998e-21 4.0217577e-24
#   5.0813797e-24 6.7289911e-23 0.0000000e+00 2.8663420e-28 0.0000000e+00]],nswer> 1
# True
